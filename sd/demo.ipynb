# %%
import model_loader
import pipeline
from PIL import Image
from transformers import CLIPTokenizer
import torch

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

ALLOW_CUDA = False
ALLOW_MPS = False

if torch.cuda.is_available() and ALLOW_CUDA:
    DEVICE = "cuda"
elif (torch.backends.mps.is_built() and torch.backends.mps.is_available()) and ALLOW_MPS:
    DEVICE = "mps"
print("Using device {DEVICE}")

tokenizer = CLIPTokenizer("../data/vocab.json",merges_file="../data/merges.txt")
model_file = "../data/v1-5-pruned-emaonly.ckpt"
models = model_loader.preload_models_from_standard_weights(model_file,DEVICE)

#TEXT TO Image

prompt = "A dog wearing a hat,highly detailed,ultra sharp,cinematic,8k resolution"
uncond_prompt = "" #you can use it as a negative prompt
do_cfg = True
cfg_scale = 7

#IMAGE TO IMAGE
input_image = None
image_path = "../images/dog.jpg"
input_image = Image.open(image_path)
strength = 0.9

sampler = "ddpm"
num_inference_steps = 50
seed = 42

output_image = pipeline.generate(
    prompt = prompt,
    uncond_prompt = uncond_prompt,
    input_image = input_image,
    strength = strength,
    do_cfg = do_cfg,
    cfg_scale = cfg_scale,
    sampler_name = sampler,
    n_inference_steps = num_inference_steps,
    seed = seed,
    models = models,
    device = DEVICE,
    idle_device = "cpu",
    tokenizer = tokenizer
)

Image.fromarray(output_image)
# Out:
# Using device {DEVICE}
# 100%|██████████| 45/45 [15:55<00:00, 21.23s/it]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
import model_loader
import pipeline
from PIL import Image
from transformers import CLIPTokenizer
import torch

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

ALLOW_CUDA = False
ALLOW_MPS = False

if torch.cuda.is_available() and ALLOW_CUDA:
    DEVICE = "cuda"
elif (torch.backends.mps.is_built() and torch.backends.mps.is_available()) and ALLOW_MPS:
    DEVICE = "mps"
print("Using device {DEVICE}")

tokenizer = CLIPTokenizer("../data/vocab.json",merges_file="../data/merges.txt")
model_file = "../data/v1-5-pruned-emaonly.ckpt"
models = model_loader.preload_models_from_standard_weights(model_file,DEVICE)

#TEXT TO Image

prompt = "A dog wearing a hat,highly detailed,ultra sharp,cinematic,8k resolution"
uncond_prompt = "" #you can use it as a negative prompt
do_cfg = True
cfg_scale = 7

#IMAGE TO IMAGE
input_image = None
image_path = "../images/dog.jpg"
input_image = Image.open(image_path)
strength = 0.9

sampler = "ddpm"
num_inference_steps = 45
seed = 42

output_image = pipeline.generate(
    prompt = prompt,
    uncond_prompt = uncond_prompt,
    input_image = input_image,
    strength = strength,
    do_cfg = do_cfg,
    cfg_scale = cfg_scale,
    sampler_name = sampler,
    n_inference_steps = num_inference_steps,
    seed = seed,
    models = models,
    device = DEVICE,
    idle_device = "cpu",
    tokenizer = tokenizer
)

Image.fromarray(output_image)
# Out:
# Using device {DEVICE}
#   8%|▊         | 3/40 [01:38<20:12, 32.78s/it]
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/share/org/BGI/bgi_wangdt/.conda/envs/df/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_1680357/4292788582.py", line 39, in <module>
#     output_image = pipeline.generate(
#   File "/share/org/BGI/bgi_wangdt/liuqifan/diffusion/stable_diffusion/sd/pipeline.py", line 100, in generate
#     model_output = diffusion(model_input,context,time_embedding)
#   File "/share/org/BGI/bgi_wangdt/.conda/envs/df/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/share/org/BGI/bgi_wangdt/.conda/envs/df/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/share/org/BGI/bgi_wangdt/liuqifan/diffusion/stable_diffusion/sd/diffusion.py", line 590, in forward
#   File "/share/org/BGI/bgi_wangdt/.conda/envs/df/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/share/org/BGI/bgi_wangdt/.conda/envs/df/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/share/org/BGI/bgi_wangdt/liuqifan/diffusion/stable_diffusion/sd/diffusion.py", line 548, in forward
#   File "/share/org/BGI/bgi_wangdt/.conda/envs/df/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/share/org/BGI/bgi_wangdt/.conda/envs/df/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/share/org/BGI/bgi_wangdt/liuqifan/diffusion/stable_diffusion/sd/diffusion.py", line 436, in forward
#   File "/share/org/BGI/bgi_wangdt/.conda/envs/df/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/share/org/BGI/bgi_wangdt/.conda/envs/df/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/share/org/BGI/bgi_wangdt/liuqifan/diffusion/stable_diffusion/sd/diffusion.py", line 372, in forward
#   File "/share/org/BGI/bgi_wangdt/.conda/envs/df/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/share/org/BGI/bgi_wangdt/.conda/envs/df/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/share/org/BGI/bgi_wangdt/liuqifan/diffusion/stable_diffusion/sd/attention.py", line 21, in forward
#     q,k,v = self.in_proj(x).chunk(3,dim = -1)
#   File "/share/org/BGI/bgi_wangdt/.conda/envs/df/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/share/org/BGI/bgi_wangdt/.conda/envs/df/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/share/org/BGI/bgi_wangdt/.conda/envs/df/lib/python3.9/site-packages/torch/nn/modules/linear.py", line 114, in forward
#     return F.linear(input, self.weight, self.bias)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/share/org/BGI/bgi_wangdt/.conda/envs/df/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 2144, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/share/org/BGI/bgi_wangdt/.conda/envs/df/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/share/org/BGI/bgi_wangdt/.conda/envs/df/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/share/org/BGI/bgi_wangdt/.conda/envs/df/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/share/org/BGI/bgi_wangdt/.conda/envs/df/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1088, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#   File "/share/org/BGI/bgi_wangdt/.conda/envs/df/lib/python3.9/site-packages/IPython/core/ultratb.py", line 970, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#   File "/share/org/BGI/bgi_wangdt/.conda/envs/df/lib/python3.9/site-packages/IPython/core/ultratb.py", line 792, in lines
#     return self._sd.lines
#   File "/share/org/BGI/bgi_wangdt/.conda/envs/df/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/share/org/BGI/bgi_wangdt/.conda/envs/df/lib/python3.9/site-packages/stack_data/core.py", line 734, in lines
#     pieces = self.included_pieces
#   File "/share/org/BGI/bgi_wangdt/.conda/envs/df/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/share/org/BGI/bgi_wangdt/.conda/envs/df/lib/python3.9/site-packages/stack_data/core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/share/org/BGI/bgi_wangdt/.conda/envs/df/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/share/org/BGI/bgi_wangdt/.conda/envs/df/lib/python3.9/site-packages/stack_data/core.py", line 660, in executing_piece
#     return only(
#   File "/share/org/BGI/bgi_wangdt/.conda/envs/df/lib/python3.9/site-packages/executing/executing.py", line 116, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0
